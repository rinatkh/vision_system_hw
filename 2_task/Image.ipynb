# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
temp_data = pd.read_csv('temp.csv', sep=" ")

# %%
temp_data.head(12)
# Out:
#       Z   T
# 0    27  71
# 1    31  64
# 2    43  52
# 3    58  41
# 4    69  33
# 5    86  23
# 6   102  17
# 7   111  12
# 8   122   2
# 9   137   0
# 10   18  87
# 11  176  -5

# %%
w = np.array([-0.0236806, 4.98004])
w1 = np.array([-0.0240125, 5.01961])

# %%
test_data = np.arange(-10, 100, 1)
test_data = test_data.reshape(len(test_data), 1)
test_data = np.hstack((test_data, np.ones((1, len(test_data))).reshape((len(test_data), 1))))
pred_test =  np.exp(test_data.dot(w))
pred_test1 =  np.exp(test_data.dot(w1))

plt.plot(test_data[:,0], pred_test, c='red', label='func')
plt.plot(test_data[:,0], pred_test1, c='blue', label='func')
plt.scatter(temp_data["T"], temp_data["Z"], label='data')

plt.xlabel('T')
plt.ylabel('Z')

plt.legend()
plt.grid()
plt.show()
